# %%
# !python traindataset2.py --dataset fishimage --model pokedex.model --labelbin lb.pickle
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# 4411
# [INFO] data matrix: 952.78MB
# (4411, 96, 96, 3)
# (4411, 483)
# [INFO] compiling model...
# 2019-04-24 01:44:11.433772: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-24 01:44:11.607062: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 81df:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-04-24 01:44:11.716175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 1 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: a2d1:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-04-24 01:44:11.716251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0, 1
# ...

# %%
# !python transfer_train.py --dataset fishmarket/img --model transfer.model --labelbin transfer_lb.pickle
# Out:
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO] data matrix: 23.98MB
# (111, 96, 96, 3)
# (111, 37)
# [INFO] compiling model...
# 2019-04-24 23:35:39.849653: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-04-24 23:35:40.028205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 81df:00:00.0
# totalMemory: 11.17GiB freeMemory: 964.94MiB
# 2019-04-24 23:35:40.157147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 1 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: a2d1:00:00.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-04-24 23:35:40.157233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0, 1
# ...
